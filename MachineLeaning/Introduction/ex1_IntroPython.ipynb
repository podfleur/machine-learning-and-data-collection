# %% [markdown]
# <a href="https://colab.research.google.com/github/podfleur/intro-ml/blob/main/MachineLeaning/Introduction/ex1_IntroPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exemples de fonctions Pandas utiles pour le TP 1

# %% [markdown]
# ## Importations des librairies utiles

# %%
import numpy as np
import pandas as pd

print('numpy %s, pandas %s'%(np.__version__,pd.__version__))
# Out:
# numpy 1.26.4, pandas 2.2.2

# %% [markdown]
# ## Creation depuis un CSV et affichage d'un Dataframe Pandas

# %%
my_dataframe = pd.read_csv('iris_incomplet.csv', dtype={'id_Iris': int})
my_dataframe
# Out:
#      id_Iris  Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# 0         23                   NaN                  NaN                   1.4
# 1        104                   4.9                  3.0                   1.4
# 2         18                   4.7                  3.2                   1.3
# 3         49                   4.6                  3.1                   1.5
# 4        123                   5.0                  3.6                   1.4
# ..       ...                   ...                  ...                   ...
# 145      124                   6.7                  3.0                   5.2
# 146       44                   6.3                  2.5                   5.0
# 147       69                   6.5                  3.0                   NaN
# 148       56                   6.2                  3.4                   5.4
# 149        5                   5.9                  3.0                   5.1
#
#      Largeur Pétale (cm)  Type Iris
# 0                    0.2          0
# 1                    0.2          0
# 2                    0.2          0
# 3                    0.2          0
# 4                    0.2          0
# ..                   ...        ...
# 145                  2.3          2
# 146                  1.9          2
# 147                  2.0          2
# 148                  2.3          2
# 149                  1.8          2
#
# [150 rows x 6 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Quelques Affichages du dataframe

# %%
my_dataframe.sample(5)
# Out:
#      id_Iris  Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# 126       82                   6.2                  2.8                   4.8
# 93        11                   5.0                  2.3                   3.3
# 104       96                   6.5                  3.0                   5.8
# 13        24                   4.3                  3.0                   1.1
# 2         18                   4.7                  3.2                   1.3
#
#      Largeur Pétale (cm)  Type Iris
# 126                  1.8          2
# 93                   1.0          1
# 104                  2.2          2
# 13                   0.1          0
# 2                    0.2          0

# %%
my_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Longueur Sépale (cm)  142 non-null    float64
#  1   Largeur Sépale (cm)   142 non-null    float64
#  2   Longueur Pétale (cm)  143 non-null    float64
#  3   Largeur Pétale (cm)   146 non-null    float64
#  4   Type Iris             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 7.0 KB

# %%
my_dataframe.mean()
# Out:
# id_Iris                 74.500000
# Longueur Sépale (cm)     5.846479
# Largeur Sépale (cm)      3.049296
# Longueur Pétale (cm)     3.756643
# Largeur Pétale (cm)      1.208219
# Type Iris                1.000000
# dtype: float64

# %%
my_dataframe.dtypes
# Out:
# id_Iris                   int64
# Longueur Sépale (cm)    float64
# Largeur Sépale (cm)     float64
# Longueur Pétale (cm)    float64
# Largeur Pétale (cm)     float64
# Type Iris                 int64
# dtype: object

# %% [markdown]
# ## Transformation d'une colonne en index

# %%
my_dataframe.set_index('id_Iris',inplace=True)
my_dataframe
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 23                        NaN                  NaN                   1.4
# 104                       4.9                  3.0                   1.4
# 18                        4.7                  3.2                   1.3
# 49                        4.6                  3.1                   1.5
# 123                       5.0                  3.6                   1.4
# ...                       ...                  ...                   ...
# 124                       6.7                  3.0                   5.2
# 44                        6.3                  2.5                   5.0
# 69                        6.5                  3.0                   NaN
# 56                        6.2                  3.4                   5.4
# 5                         5.9                  3.0                   5.1
#
#          Largeur Pétale (cm)  Type Iris
# id_Iris
# 23                       0.2          0
# 104                      0.2          0
# 18                       0.2          0
# 49                       0.2          0
# 123                      0.2          0
# ...                      ...        ...
# 124                      2.3          2
# 44                       1.9          2
# 69                       2.0          2
# 56                       2.3          2
# 5                        1.8          2
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Tri selon l'index

# %%
my_dataframe.sort_index(inplace=True) #Inplace permet de conserver les modification du DataFrame
my_dataframe
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 0                         4.9                  3.1                   1.5
# 1                         5.3                  3.7                   1.5
# 2                         6.7                  3.1                   4.4
# 3                         5.0                  3.0                   1.6
# 4                         5.7                  NaN                   4.2
# ...                       ...                  ...                   ...
# 145                       6.5                  2.8                   4.6
# 146                       6.0                  2.2                   4.0
# 147                       4.6                  3.4                   1.4
# 148                       7.3                  2.9                   NaN
# 149                       6.8                  3.2                   5.9
#
#          Largeur Pétale (cm)  Type Iris
# id_Iris
# 0                        0.2          0
# 1                        0.2          0
# 2                        1.4          1
# 3                        0.2          0
# 4                        1.3          1
# ...                      ...        ...
# 145                      1.5          1
# 146                      1.0          1
# 147                      0.3          0
# 148                      1.8          2
# 149                      2.3          2
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Sélection d'une colonne de Dataframe

# %%
my_dataframe['Largeur Sépale (cm)']
# Out:
# id_Iris
# 0      3.1
# 1      3.7
# 2      3.1
# 3      3.0
# 4      NaN
#       ...
# 145    2.8
# 146    2.2
# 147    3.4
# 148    2.9
# 149    3.2
# Name: Largeur Sépale (cm), Length: 150, dtype: float64

# %% [markdown]
# ## Sélection d'une sous-partie de Dataframe (Slice) avec loc

# %%
my_dataframe.loc[124:128,'Largeur Sépale (cm)':'Largeur Pétale (cm)']

# %%
mon_petit_dataframe = my_dataframe.loc[145:,['Longueur Sépale (cm)','Longueur Pétale (cm)','Type Iris']]
mon_petit_dataframe

# %% [markdown]
# ## Filtre

# %%
display(mon_petit_dataframe['Longueur Pétale (cm)']>4)
mon_petit_dataframe[mon_petit_dataframe['Longueur Pétale (cm)']>4]

# %% [markdown]
# ## Modification en masse (Vectorisation)

# %%
mon_petit_dataframe * 2

# %%
mon_petit_dataframe['Longueur Pétale (cm)'] = mon_petit_dataframe['Longueur Pétale (cm)'] -1
mon_petit_dataframe

# %% [markdown]
# ## Agrégation avec Groupby

# %%
my_dataframe.groupby("Type Iris")["Largeur Pétale (cm)"].mean()

# %% [markdown]
# ## Conversion en Numpy

# %%
my_array=mon_petit_dataframe.values
print(type(my_array))
my_array

# %% [markdown]
# ## Quelques opérations NumPy

# %%
my_array[3,2]

# %%
my_array[-1,1]

# %%
my_array + 1

# %%
my_array + np.array([1,2,3])

# %%
my_array == 1

# %%
np.isnan(my_array)

# %%
my_array[np.isnan(my_array)]=0
my_array

# %%
my_array.reshape(3, 5)

# %%
my_doublearray = np.concatenate([my_array,my_array])
display(my_doublearray)
my_doublearray.shape

# %%
my_doublearray.reshape(3, 5, 2)
